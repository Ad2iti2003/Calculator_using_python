# %%
def add(a,b):
  return a + b

def subtract(a,b):
  return a - b


def multiply(a,b):
  return a * b


def Div(a,b):
  if b==0:
    return "cannot divisival by zero!"

  return a/b


while True:
  print("\n1. Add")
  print("2. Subtraction")
  print("3. Multiply")
  print("4. Division")
  print("5. Exit")


  choice = input("Enter your choice")
  if choice == "5":
    break


  num1 = float(input("Enter 1st number:"))
  num2 = float(input("Enter 2nd number:"))

  if(choice == '1'):
    print("result :", add(num1,num2))
  elif(choice == '2'):
    print("result :", subtract(num1,num2))
  elif(choice == '3'):
    print("result :", multiply(num1,num2))
  elif(choice == '4'):
    print("result :", Div(num1,num2))
  else:
    print("Invalid choice")
# Out:
# 1. Add
# 2. Subtraction
# 3. Multiply
# 4. Division
# 5. Exit
# Enter your choice3
# Enter 1st number:23
# Enter 2nd number:50
# result : 1150.0
#
# 1. Add
# 2. Subtraction
# 3. Multiply
# 4. Division
# 5. Exit
# Enter your choice45
# Enter 1st number:5
# Enter 2nd number:50
# Invalid choice
#
# 1. Add
# 2. Subtraction
# 3. Multiply
# 4. Division
# 5. Exit
# Enter your choice2
# Enter 1st number:45
# Enter 2nd number:76
# result : -31.0
#
# 1. Add
# 2. Subtraction
# 3. Multiply
# 4. Division
# 5. Exit
# Enter your choice5
